# %% [markdown]
# # Week 2 — The model is just a rule you can read
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThirafiQaedi/flyrank-Starter-Notebooks/blob/main/notebooks/02_your_first_readable_model.ipynb)
#
# You'll:
# 1. Write a **1-line hand rule** and rank pages with it.
# 2. Fit a **depth-2 decision tree** and `print` it — the model "learned" a readable if/else. Then compare — where does it beat your rule, and where doesn’t it?
# 3. See **why you never feed the outcome back in** — that's leakage.
#
# The payoff isn't a high score. It's: *my intuition was rough, the model found the real signal, and I can read exactly what it found.*

# %% [markdown]
# ## 0. Setup (Colab or local)

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages |  declining rate: 0.542

# %% [markdown]
# ## 1. A rule you write by hand: `stale x visible`
# Intuition: a page worth reviewing is one that is **stale** (not updated in a while) **and** still **visible** (getting impressions). Rank those by how much exposure they have.

# %%
stale   = (df["days_since_last_update"] >= 180).astype(int)
visible = (df["impressions_90d"] >= 500).astype(int)
df["hand_rule_score"] = stale * visible * df["impressions_90d"]

top10 = df.sort_values("hand_rule_score", ascending=False).head(10)
top10[["impressions_90d", "days_since_last_update", "avg_position", "ctr", "trend_direction"]]
# Out:
#        impressions_90d  days_since_last_update  avg_position   ctr  \
# 16751            61678                     194          19.7  0.15
# 16514            59472                     194          24.8  0.13
# 7021             25715                     194          22.2  0.23
# 21268            13299                     193          10.5  0.49
# 11489             7812                     194          39.0  0.01
# 12045             7558                     193          17.9  0.20
# 698               4590                     194          31.0  0.00
# 5327              4556                     194          16.4  0.33
# 26810             4429                     194          25.3  0.38
# 20837             1697                     193          15.8  0.12
#
#       trend_direction
# 16751            down
# 16514            down
# 7021             down
# 21268            down
# 11489            down
# 12045            down
# 698              down
# 5327             down
# 26810            down
# 20837            down

# %% [markdown]
# We need a way to score any ranking. **Precision@K** = of the top K pages a ranking flags, what fraction are actually declining.

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

y = df["is_declining_label"].values
for k in (20, 50):
    print(f"Hand rule  Precision@{k}: {precision_at_k(df['hand_rule_score'], y, k):.3f}")
# Out:
# Hand rule  Precision@20: 0.900
# Hand rule  Precision@50: 0.680

# %% [markdown]
# ## 2. Let a model learn the rule — then read it
# A **depth-2 decision tree** can only ask 3 yes/no questions. That constraint is the point: whatever it learns, you can read.
#
# We give it a few **pre-decision** signals — never product flags.

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0

# %% [markdown]
# That printout **is** the model — a human-readable if/else. Now rank pages by the tree's probability and score it the same way.

# %%
tree_score = tree.predict_proba(X)[:, 1]
for k in (20, 50):
    hr = precision_at_k(df["hand_rule_score"], y, k)
    tr = precision_at_k(tree_score, y, k)
    print(f"Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")
# Out:
# Precision@20:  hand rule 0.900   vs   tree 0.550
# Precision@50:  hand rule 0.680   vs   tree 0.600

# %% [markdown]
# Look closely: the tree **wins at Precision@50** but your hand rule **wins at Precision@20**. Both results are real. A sharp human rule can be excellent at the very top of the list; the model's advantage shows up deeper, where simple rules run out of signal. Saying exactly that — instead of "the model is better" — is what honest evaluation sounds like.

# %% [markdown]
# ## 3. Why you can't feed the outcome back in
# Your label is `trend_direction == "down"`, and `trend_pct` is the exact percentage change that bucket is computed from — so it **is** the answer in disguise. Watch what happens if you feed it in as a feature:

# %%
X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42).fit(X_leaky, y)
print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f}  <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))
# Out:
# 'Leaky' tree Precision@50: 1.000  <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- word_count <= 212.00
# |   |   |--- class: 1
# |   |--- word_count >  212.00
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0

# %% [markdown]
# The tree just split on `trend_pct` and nailed the label — because the label is **derived from** `trend_pct`. That's **leakage**: the feature is the answer in disguise, and it teaches you nothing.
#
# That's also why the starter data ships **only observable signals** — the product's own decision flags (health scores, "needs CTR fix", and so on) aren't included, so you can't accidentally train on them. You build from what was knowable *before* the outcome.
#
# > Rule of thumb: if a feature would only be known *because someone already made the decision you're predicting*, it leaks. Leave it out.

# %% [markdown]
# ## 4. 🔧 Your turn
# - Change `max_depth` to 3 or 4 — does Precision@50 improve? Can you still read the tree?
# - Swap in different features (drop `impressions_90d`, add `engagement_rate`). What does the tree choose to split on first?
# - **Important caveat:** we scored *in-sample* here for teaching. The real pipeline uses **client-holdout** validation (`scripts/03_train_model.py`) so a client's pages never appear in both train and test. Re-run your comparison with a train/test split and see if the gap holds.
#
# Write your experiment below.

# %%
# Your experiment here

# %% [markdown]
# - Change `max_depth` to 3 or 4 — does Precision@50 improve? Can you still read the tree?

# %%
features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=50, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- impressions_90d <= 3.50
# |   |   |   |--- word_count <= 687.00
# |   |   |   |   |--- impressions_90d <= 2.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- impressions_90d >  2.50
# |   |   |   |   |   |--- days_since_last_update <= 62.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- days_since_last_update >  62.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  687.00
# |   |   |   |   |--- days_since_last_update <= 56.00
# |   |   |   |   |   |--- days_since_last_update <= 3.50
# |   |   |   |   |   |   |--- word_count <= 3019.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- word_count >  3019.00
# |   |   |   |   |   |   |   |--- word_count <= 3298.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- word_count >  3298.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- days_since_last_update >  3.50
# |   |   |   |   |   |   |--- avg_position <= 0.60
# |   |   |   |   |   |   |   |--- content_age_days <= 310.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- content_age_days >  310.50
# |   |   |   |   |   |   |   |   |--- word_count <= 1447.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- word_count >  1447.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 1450.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  1450.00
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 311.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  311.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- avg_position >  0.60
# |   |   |   |   |   |   |   |--- content_age_days <= 124.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- content_age_days >  124.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- days_since_last_update >  56.00
# |   |   |   |   |   |--- days_since_last_update <= 95.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- days_since_last_update >  95.00
# |   |   |   |   |   |   |--- content_age_days <= 323.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- content_age_days >  323.00
# |   |   |   |   |   |   |   |--- content_age_days <= 343.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- content_age_days >  343.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- impressions_90d >  3.50
# |   |   |   |--- content_age_days <= 237.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- content_age_days >  237.50
# |   |   |   |   |--- word_count <= 1401.00
# |   |   |   |   |   |--- content_age_days <= 309.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- content_age_days >  309.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- word_count >  1401.00
# |   |   |   |   |   |--- class: 1
# |   |--- avg_position >  0.75
# |   |   |--- content_age_days <= 108.50
# |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |--- content_age_days <= 93.50
# |   |   |   |   |   |--- avg_position <= 4.75
# |   |   |   |   |   |   |--- word_count <= 2748.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- word_count >  2748.00
# |   |   |   |   |   |   |   |--- word_count <= 3149.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 3.75
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2856.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  2856.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- avg_position >  3.75
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- word_count >  3149.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- avg_position >  4.75
# |   |   |   |   |   |   |--- word_count <= 3314.00
# |   |   |   |   |   |   |   |--- word_count <= 3209.00
# |   |   |   |   |   |   |   |   |--- word_count <= 2671.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 22.60
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2443.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2443.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_position >  22.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  2671.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2920.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2920.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2804.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2804.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- word_count >  3209.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- word_count >  3314.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- content_age_days >  93.50
# |   |   |   |   |   |--- word_count <= 3663.50
# |   |   |   |   |   |   |--- word_count <= 2778.00
# |   |   |   |   |   |   |   |--- word_count <= 2292.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  2292.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 15.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  15.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2682.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- word_count >  2682.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- word_count >  2778.00
# |   |   |   |   |   |   |   |--- word_count <= 2877.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  2877.00
# |   |   |   |   |   |   |   |   |--- avg_position <= 19.25
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 8.40
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 6.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  6.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- avg_position >  8.40
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  19.25
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 25.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_position >  25.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- word_count >  3663.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |--- impressions_90d <= 2.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- impressions_90d >  2.50
# |   |   |   |   |   |--- days_since_last_update <= 97.00
# |   |   |   |   |   |   |--- word_count <= 3462.00
# |   |   |   |   |   |   |   |--- word_count <= 3292.00
# |   |   |   |   |   |   |   |   |--- word_count <= 2875.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2845.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- word_count >  2845.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  2875.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  3292.00
# |   |   |   |   |   |   |   |   |--- word_count <= 3423.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  3423.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- word_count >  3462.00
# |   |   |   |   |   |   |   |--- avg_position <= 9.20
# |   |   |   |   |   |   |   |   |--- word_count <= 3839.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 2.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_position >  2.55
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- word_count >  3839.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- avg_position >  9.20
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- days_since_last_update >  97.00
# |   |   |   |   |   |   |--- word_count <= 3846.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- word_count >  3846.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- content_age_days >  108.50
# |   |   |   |--- impressions_90d <= 2.50
# |   |   |   |   |--- avg_position <= 4.75
# |   |   |   |   |   |--- impressions_90d <= 1.50
# |   |   |   |   |   |   |--- content_age_days <= 474.50
# |   |   |   |   |   |   |   |--- word_count <= 3333.50
# |   |   |   |   |   |   |   |   |--- word_count <= 1052.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 895.00
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 301.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  301.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- word_count >  895.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  1052.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 1623.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- word_count >  1623.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1634.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1634.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- word_count >  3333.50
# |   |   |   |   |   |   |   |   |--- word_count <= 3586.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  3586.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- avg_position >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 4833.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  4833.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- content_age_days >  474.50
# |   |   |   |   |   |   |   |--- avg_position <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- avg_position >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- impressions_90d >  1.50
# |   |   |   |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |   |   |   |--- content_age_days <= 125.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 114.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- content_age_days >  114.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- content_age_days >  125.50
# |   |   |   |   |   |   |   |   |--- word_count <= 2490.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 135.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  135.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  2490.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |   |   |   |--- word_count <= 905.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  905.00
# |   |   |   |   |   |   |   |   |--- word_count <= 906.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  906.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 328.00
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update <= 100.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update >  100.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  328.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 3.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  3.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- avg_position >  4.75
# |   |   |   |   |   |--- word_count <= 4311.50
# |   |   |   |   |   |   |--- days_since_last_update <= 100.00
# |   |   |   |   |   |   |   |--- word_count <= 3328.00
# |   |   |   |   |   |   |   |   |--- content_age_days <= 288.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2071.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1919.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1919.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  2071.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 7.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  7.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- content_age_days >  288.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 743.00
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 498.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  498.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- word_count >  743.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1537.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1537.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- word_count >  3328.00
# |   |   |   |   |   |   |   |   |--- content_age_days <= 226.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 3447.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 3422.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  3422.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  3447.50
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- content_age_days >  226.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 46.75
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- avg_position >  46.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- days_since_last_update >  100.00
# |   |   |   |   |   |   |   |--- content_age_days <= 129.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- content_age_days >  129.00
# |   |   |   |   |   |   |   |   |--- avg_position <= 9.25
# |   |   |   |   |   |   |   |   |   |--- word_count <= 1642.50
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 286.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  286.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- word_count >  1642.50
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update <= 167.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update >  167.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  9.25
# |   |   |   |   |   |   |   |   |   |--- days_since_last_update <= 372.50
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 491.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  491.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- days_since_last_update >  372.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- word_count >  4311.50
# |   |   |   |   |   |   |--- avg_position <= 97.00
# |   |   |   |   |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- avg_position >  97.00
# |   |   |   |   |   |   |   |--- content_age_days <= 230.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- content_age_days >  230.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- impressions_90d >  2.50
# |   |   |   |   |--- days_since_last_update <= 95.00
# |   |   |   |   |   |--- word_count <= 2949.50
# |   |   |   |   |   |   |--- impressions_90d <= 4.50
# |   |   |   |   |   |   |   |--- days_since_last_update <= 21.00
# |   |   |   |   |   |   |   |   |--- content_age_days <= 110.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- content_age_days >  110.00
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 531.00
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 305.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  305.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  531.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- days_since_last_update >  21.00
# |   |   |   |   |   |   |   |   |--- word_count <= 1696.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 153.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  153.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1612.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1612.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- word_count >  1696.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- impressions_90d >  4.50
# |   |   |   |   |   |   |   |--- content_age_days <= 291.50
# |   |   |   |   |   |   |   |   |--- word_count <= 2783.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 9.70
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 747.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  747.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- avg_position >  9.70
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 16.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  16.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- word_count >  2783.00
# |   |   |   |   |   |   |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- content_age_days >  291.50
# |   |   |   |   |   |   |   |   |--- word_count <= 1439.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 60.90
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 6.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  6.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- avg_position >  60.90
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 334.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  334.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  1439.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- word_count >  2949.50
# |   |   |   |   |   |   |--- content_age_days <= 122.00
# |   |   |   |   |   |   |   |--- word_count <= 3263.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 110.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 10.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- avg_position >  10.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- content_age_days >  110.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- word_count >  3263.50
# |   |   |   |   |   |   |   |   |--- word_count <= 3589.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  3589.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 36.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  36.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 17.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  17.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- content_age_days >  122.00
# |   |   |   |   |   |   |   |--- content_age_days <= 181.00
# |   |   |   |   |   |   |   |   |--- avg_position <= 2.40
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 1.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_position >  1.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  2.40
# |   |   |   |   |   |   |   |   |   |--- word_count <= 5179.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2957.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2957.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- word_count >  5179.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- content_age_days >  181.00
# |   |   |   |   |   |   |   |   |--- word_count <= 4543.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 3963.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 3760.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  3760.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- word_count >  3963.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 4277.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  4277.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- word_count >  4543.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 306.00
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  306.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- days_since_last_update >  95.00
# |   |   |   |   |   |--- content_age_days <= 327.00
# |   |   |   |   |   |   |--- avg_position <= 11.95
# |   |   |   |   |   |   |   |--- impressions_90d <= 3.50
# |   |   |   |   |   |   |   |   |--- days_since_last_update <= 100.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 1889.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- word_count >  1889.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- days_since_last_update >  100.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- impressions_90d >  3.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 145.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- content_age_days >  145.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 4983.50
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 311.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  311.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- word_count >  4983.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- avg_position >  11.95
# |   |   |   |   |   |   |   |--- avg_position <= 13.30
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- avg_position >  13.30
# |   |   |   |   |   |   |   |   |--- content_age_days <= 314.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 225.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  225.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1420.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1420.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- content_age_days >  314.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- content_age_days >  327.00
# |   |   |   |   |   |   |--- word_count <= 2704.00
# |   |   |   |   |   |   |   |--- word_count <= 1579.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 6.65
# |   |   |   |   |   |   |   |   |   |--- ctr <= 16.67
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 332.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  332.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- ctr >  16.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  6.65
# |   |   |   |   |   |   |   |   |   |--- ctr <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ctr >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  1579.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- word_count >  2704.00
# |   |   |   |   |   |   |   |--- class: 1
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- ctr <= 0.33
# |   |   |   |--- impressions_90d <= 73.50
# |   |   |   |   |--- content_age_days <= 104.50
# |   |   |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |   |   |--- impressions_90d <= 7.50
# |   |   |   |   |   |   |   |--- word_count <= 2484.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  2484.50
# |   |   |   |   |   |   |   |   |--- word_count <= 2761.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 16.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- avg_position >  16.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- word_count >  2761.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 17.95
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2898.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2898.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- avg_position >  17.95
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- impressions_90d >  7.50
# |   |   |   |   |   |   |   |--- impressions_90d <= 30.50
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 20.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 18.90
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 3558.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  3558.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- avg_position >  18.90
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- impressions_90d >  20.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 40.10
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 7.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  7.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- avg_position >  40.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- impressions_90d >  30.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 6.75
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 62.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 6.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  6.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  62.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- avg_position >  6.75
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 15.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- avg_position >  15.40
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 17.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  17.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |   |   |--- impressions_90d <= 68.00
# |   |   |   |   |   |   |   |--- word_count <= 4017.50
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 13.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 90.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  90.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 13.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  13.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- impressions_90d >  13.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 83.45
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 51.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  51.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- avg_position >  83.45
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 94.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  94.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- word_count >  4017.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 31.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 47.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  47.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 4292.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  4292.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  31.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 90.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  90.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- impressions_90d >  68.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- content_age_days >  104.50
# |   |   |   |   |   |--- impressions_90d <= 14.50
# |   |   |   |   |   |   |--- word_count <= 1149.50
# |   |   |   |   |   |   |   |--- impressions_90d <= 9.50
# |   |   |   |   |   |   |   |   |--- word_count <= 869.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- word_count >  869.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 266.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  266.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 988.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  988.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- impressions_90d >  9.50
# |   |   |   |   |   |   |   |   |--- word_count <= 859.00
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 308.50
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 284.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  284.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  308.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 4.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  4.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  859.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 5.75
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 875.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  875.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- avg_position >  5.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- word_count >  1149.50
# |   |   |   |   |   |   |   |--- days_since_last_update <= 4.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 13.95
# |   |   |   |   |   |   |   |   |   |--- word_count <= 3016.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  3016.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 8.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  8.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  13.95
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2510.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  2510.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- days_since_last_update >  4.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 177.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2727.00
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 145.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  145.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- word_count >  2727.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 9.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  9.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- content_age_days >  177.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 20.55
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 3820.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  3820.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- avg_position >  20.55
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1441.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1441.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |--- impressions_90d >  14.50
# |   |   |   |   |   |   |--- days_since_last_update <= 24.00
# |   |   |   |   |   |   |   |--- avg_position <= 17.45
# |   |   |   |   |   |   |   |   |--- content_age_days <= 110.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 8.55
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 106.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  106.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- avg_position >  8.55
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2903.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2903.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- content_age_days >  110.50
# |   |   |   |   |   |   |   |   |   |--- word_count <= 3860.50
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |--- word_count >  3860.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 3.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  3.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |--- avg_position >  17.45
# |   |   |   |   |   |   |   |   |--- content_age_days <= 126.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2731.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 31.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  31.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- word_count >  2731.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2825.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2825.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- content_age_days >  126.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 963.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  963.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 3524.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  3524.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- days_since_last_update >  24.00
# |   |   |   |   |   |   |   |--- content_age_days <= 274.00
# |   |   |   |   |   |   |   |   |--- content_age_days <= 135.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1591.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1591.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 3.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  3.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- content_age_days >  135.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 65.20
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 20.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  20.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- avg_position >  65.20
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 162.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  162.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- content_age_days >  274.00
# |   |   |   |   |   |   |   |   |--- avg_position <= 10.45
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 276.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1440.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1440.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  276.50
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- avg_position >  10.45
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 309.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 4188.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  4188.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  309.50
# ...
# |   |   |   |   |   |   |   |   |--- avg_position >  43.15
# |   |   |   |   |   |   |   |   |   |--- ctr <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 44.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  44.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |--- ctr >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- impressions_90d >  121.50
# |   |   |   |   |   |   |--- avg_position <= 32.45
# |   |   |   |   |   |   |   |--- impressions_90d <= 1255.50
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 1242.00
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 509.50
# |   |   |   |   |   |   |   |   |   |   |--- ctr <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- ctr >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  509.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- impressions_90d >  1242.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- impressions_90d >  1255.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 418.00
# |   |   |   |   |   |   |   |   |   |--- ctr <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- ctr >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 3586.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  3586.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- content_age_days >  418.00
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 2214.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 32.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  32.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  2214.00
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 3491.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  3491.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- avg_position >  32.45
# |   |   |   |   |   |   |   |--- content_age_days <= 439.50
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 144.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 54.95
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 132.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  132.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- avg_position >  54.95
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 403.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  403.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- impressions_90d >  144.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 429.50
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days <= 420.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- content_age_days >  420.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  429.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 77.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  77.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- content_age_days >  439.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 503.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 77.25
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 401.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  401.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- avg_position >  77.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- content_age_days >  503.00
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 541.00
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 71.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  71.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  541.00
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 2068.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  2068.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- word_count >  1027.00
# |   |   |   |   |--- content_age_days <= 336.00
# |   |   |   |   |   |--- impressions_90d <= 26.50
# |   |   |   |   |   |   |--- avg_position <= 63.40
# |   |   |   |   |   |   |   |--- impressions_90d <= 18.00
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 6.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- impressions_90d >  6.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- impressions_90d >  18.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- avg_position >  63.40
# |   |   |   |   |   |   |   |--- word_count <= 1306.50
# |   |   |   |   |   |   |   |   |--- avg_position <= 82.35
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- avg_position >  82.35
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- word_count >  1306.50
# |   |   |   |   |   |   |   |   |--- word_count <= 1344.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- word_count >  1344.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- impressions_90d >  26.50
# |   |   |   |   |   |   |--- content_age_days <= 326.50
# |   |   |   |   |   |   |   |--- impressions_90d <= 1202.50
# |   |   |   |   |   |   |   |   |--- word_count <= 2995.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 405.50
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 250.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  250.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  405.50
# |   |   |   |   |   |   |   |   |   |   |--- ctr <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- ctr >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- word_count >  2995.50
# |   |   |   |   |   |   |   |   |   |--- content_age_days <= 320.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- content_age_days >  320.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- impressions_90d >  1202.50
# |   |   |   |   |   |   |   |   |--- days_since_last_update <= 13.50
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 26.30
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2788.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2788.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- avg_position >  26.30
# |   |   |   |   |   |   |   |   |   |   |--- ctr <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- ctr >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- days_since_last_update >  13.50
# |   |   |   |   |   |   |   |   |   |--- ctr <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- ctr <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- ctr >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ctr >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2209.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2209.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- content_age_days >  326.50
# |   |   |   |   |   |   |   |--- avg_position <= 45.40
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 83276.00
# |   |   |   |   |   |   |   |   |   |--- ctr <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 1168.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  1168.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ctr >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update <= 72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- days_since_last_update >  72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- impressions_90d >  83276.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- avg_position >  45.40
# |   |   |   |   |   |   |   |   |--- word_count <= 1456.50
# |   |   |   |   |   |   |   |   |   |--- ctr <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 46.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  46.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- ctr >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- word_count >  1456.50
# |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 459.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- impressions_90d >  459.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- content_age_days >  336.00
# |   |   |   |   |   |--- days_since_last_update <= 9.00
# |   |   |   |   |   |   |--- ctr <= 0.46
# |   |   |   |   |   |   |   |--- days_since_last_update <= 6.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- days_since_last_update >  6.00
# |   |   |   |   |   |   |   |   |--- avg_position <= 28.75
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 28.55
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 2382.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  2382.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- avg_position >  28.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- avg_position >  28.75
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- ctr >  0.46
# |   |   |   |   |   |   |   |--- content_age_days <= 462.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- content_age_days >  462.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- days_since_last_update >  9.00
# |   |   |   |   |   |   |--- days_since_last_update <= 12.00
# |   |   |   |   |   |   |   |--- avg_position <= 56.30
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 99.00
# |   |   |   |   |   |   |   |   |   |--- avg_position <= 33.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- avg_position >  33.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- impressions_90d >  99.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2731.50
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2717.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2717.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- word_count >  2731.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- avg_position >  56.30
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 1576.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- impressions_90d >  1576.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- days_since_last_update >  12.00
# |   |   |   |   |   |   |   |--- days_since_last_update <= 22.50
# |   |   |   |   |   |   |   |   |--- content_age_days <= 465.00
# |   |   |   |   |   |   |   |   |   |--- ctr <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- ctr >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 25.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  25.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- content_age_days >  465.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 2740.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- word_count >  2740.00
# |   |   |   |   |   |   |   |   |   |   |--- word_count <= 2990.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- word_count >  2990.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- days_since_last_update >  22.50
# |   |   |   |   |   |   |   |   |--- impressions_90d <= 17174.00
# |   |   |   |   |   |   |   |   |   |--- word_count <= 1321.50
# |   |   |   |   |   |   |   |   |   |   |--- avg_position <= 29.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- avg_position >  29.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- word_count >  1321.50
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- impressions_90d >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- impressions_90d >  17174.00
# |   |   |   |   |   |   |   |   |   |--- class: 1

# %% [markdown]
# Yes still can read the tree

# %% [markdown]
# - Swap in different features (drop `impressions_90d`, add `engagement_rate`). What does the tree choose to split on first?

# %%
features = ["content_age_days", "days_since_last_update", "engagement_rate",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=5, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- avg_position <= 0.55
# |   |--- avg_position <= 0.15
# |   |   |--- word_count <= 669.50
# |   |   |   |--- engagement_rate <= 50.00
# |   |   |   |   |--- content_age_days <= 386.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- content_age_days >  386.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- engagement_rate >  50.00
# |   |   |   |   |--- class: 1
# |   |   |--- word_count >  669.50
# |   |   |   |--- days_since_last_update <= 3.50
# |   |   |   |   |--- word_count <= 3019.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- word_count >  3019.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- days_since_last_update >  3.50
# |   |   |   |   |--- days_since_last_update <= 56.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- days_since_last_update >  56.00
# |   |   |   |   |   |--- class: 0
# |   |--- avg_position >  0.15
# |   |   |--- days_since_last_update <= 62.00
# |   |   |   |--- word_count <= 1653.50
# |   |   |   |   |--- word_count <= 687.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- word_count >  687.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  1653.50
# |   |   |   |   |--- word_count <= 2083.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- word_count >  2083.00
# |   |   |   |   |   |--- class: 0
# |   |   |--- days_since_last_update >  62.00
# |   |   |   |--- class: 1
# |--- avg_position >  0.55
# |   |--- content_age_days <= 287.50
# |   |   |--- ctr <= 0.33
# |   |   |   |--- content_age_days <= 172.50
# |   |   |   |   |--- days_since_last_update <= 11.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- days_since_last_update >  11.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- content_age_days >  172.50
# |   |   |   |   |--- content_age_days <= 177.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- content_age_days >  177.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- ctr >  0.33
# |   |   |   |--- ctr <= 4.52
# |   |   |   |   |--- engagement_rate <= 0.21
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- engagement_rate >  0.21
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- ctr >  4.52
# |   |   |   |   |--- ctr <= 25.73
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- ctr >  25.73
# |   |   |   |   |   |--- class: 0
# |   |--- content_age_days >  287.50
# |   |   |--- avg_position <= 38.45
# |   |   |   |--- days_since_last_update <= 25.50
# |   |   |   |   |--- days_since_last_update <= 9.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- days_since_last_update >  9.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- days_since_last_update >  25.50
# |   |   |   |   |--- word_count <= 1079.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- word_count >  1079.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- avg_position >  38.45
# |   |   |   |--- word_count <= 1137.50
# |   |   |   |   |--- ctr <= 0.20
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- ctr >  0.20
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  1137.50
# |   |   |   |   |--- avg_position <= 60.40
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- avg_position >  60.40
# |   |   |   |   |   |--- class: 0

# %% [markdown]
# Tree split change from `impressions_90d`to `word_count`

# %% [markdown]
# - **Important caveat:** we scored *in-sample* here for teaching. The real pipeline uses **client-holdout** validation (`scripts/03_train_model.py`) so a client's pages never appear in both train and test. Re-run your comparison with a train/test split and see if the gap holds.

# %% [markdown]
# ### Save your work
# **Colab:** *File → Save a copy in GitHub* (your submission) and *File → Save a copy in Drive*.
#
# You now have the two core reflexes of applied ML: **discover before you model**, and **prefer a model you can read and can't fool**. That's the whole foundation the capstone builds on.
